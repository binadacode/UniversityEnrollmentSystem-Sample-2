# %% [markdown]
# <a href="https://colab.research.google.com/github/binadacode/UniversityEnrollmentSystem-Sample-2/blob/main/RiceVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print " Hello World";
print(2+2)
# Out:
#   File "/tmp/ipython-input-1047630487.py", line 1
#     print " Hello World";
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(2+2+2)
